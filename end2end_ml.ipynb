# %% [markdown]
# # End 2 End Project - ML
#
# ![image.png](attachment:45c610dc-c91c-49aa-ae1b-74a8f4598c90.png)

# %% [markdown]
# 1- Create github repository

# %% [markdown]
# ![image.png](attachment:46ebb8e6-d286-4f06-892f-121630321516.png)

# %% [markdown]
# 2- open anaconda prompt terminal and browse to the folder location:

# %% [markdown]
# ![image.png](attachment:3158ef2a-a113-4c7a-8461-8e230bfc27be.png)

# %% [markdown]
# * lunch the vcode instance

# %% [markdown]
# ![image.png](attachment:26b3b282-67fb-4c5b-b12b-6069718a592a.png)

# %% [markdown]
# ![image.png](attachment:5a7e1ab1-3ccd-4e7c-a60a-2c443072ec49.png)

# %% [markdown]
# * create environment, you can use the bash terminal as well

# %% [markdown]
# ![image.png](attachment:9eaef418-408a-4e51-be9e-4455aee5f1c5.png)

# %% [markdown]
# * having issues with conda
#
# ![image.png](attachment:6b039381-2e21-4e09-ab59-b65c08194951.png)

# %% [markdown]
# * checking for the active conda
#
# ![image.png](attachment:a8b894b1-07de-421b-b432-6b7fdde3f4fb.png)

# %% [markdown]
# * Create a read me file
#
# ![image.png](attachment:fb7e9691-55d4-4bff-bfb3-575d51db8a8f.png)

# %% [markdown]
# * GIT INIT
#
# ![image.png](attachment:4d049644-4d2d-4cb1-bde8-63388cd5fe25.png)

# %% [markdown]
# ![image.png](attachment:b1ba3411-51dc-4f79-b223-0abdf2f21b70.png)

# %% [markdown]
# * create the .gitignore file from within github
#
# ![image.png](attachment:7f6406a0-c69d-4d52-b947-1dbfe7af30ac.png)

# %% [markdown]
# * once the .gitignore file is created
# * pull the file into the local machine, since we do not want everything to be committed, such as environments
#
# ![image.png](attachment:65fc9530-cbdf-4761-8774-b2f9b25996a3.png)

# %% [markdown]
# * add these two files
#
# ![image.png](attachment:10ffbd9e-2820-40e5-8ac7-b779ba70860e.png)
#
# * setup.py - responsible for creating the ml application as a package.
#
# ![image.png](attachment:bd17194e-3f68-4fa8-881b-209ec277d81c.png)
#
# * here, the find_packages() will look for folders that have __init__.py file in it, and treat them as packages.
#
# ![image.png](attachment:15f9a0d0-0b16-4ed2-b574-1877a6acaf73.png)

# %% [markdown]
# * -e . in python makes the setup.py to automatically run
#
# ![image.png](attachment:744cf250-8118-4e2b-81b4-a755c46fd489.png)

# %% [markdown]
# * install the requirements file
#
# ![image.png](attachment:13737382-de01-4d88-b0dc-a6d7fc895bac.png)
#
# ![image.png](attachment:6a55fabf-d90d-46fb-8d2a-2120e0bca69c.png)

# %% [markdown]
# # program structure
#
# * components folder - holds the different data procedures such as ingestion, trasnformation and model training
# * pipelin folder - contains the prediction and training pipelines
# * add also the exception handling, logging and utilities procedures
#
#
# ![image.png](attachment:13a58c9a-ed02-4aaa-8e33-57e30d350d1d.png)

# %% [markdown]
# ![image.png](attachment:c7af762a-387e-4d25-8e8c-e0c12e810f2d.png)

# %% [markdown]
# ![image.png](attachment:1068ed3a-0122-429d-939d-334c71cf5a84.png)

# %% [markdown]
# * checking if logger is working
#
# ![image.png](attachment:244930c1-7e2f-4cb4-af6e-f537c86f9d15.png)

# %% [markdown]
# * checking if the exception is working, a small change in the .py was performed "division by zero" to check the exception
#
# ![image.png](attachment:325639d5-f968-474b-a40d-0513813e2250.png)

# %% [markdown]
# * install more libraries,  -e got commented so it does not recreate the setup.py again
#
# ![image.png](attachment:2feb021d-d87f-4847-8719-cb0507db789b.png)

# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ![image.png](attachment:037f86b7-d6c7-4c1b-bed1-68cf8e5a940d.png)

# %% [markdown]
# * dataclass
#
# ![image.png](attachment:8b6f7daa-4534-4357-b6c9-8f2cc96d6f3d.png)
#
# ![image.png](attachment:0351f0bd-0010-4556-8bd0-59178e362c64.png)

# %% [markdown]
# ![image.png](attachment:b20bd21f-17e4-42ba-92cb-4d9f1bcb3fda.png)

# %% [markdown]
# # Data Transformation

# %% [markdown]
# * requirements.txt file updated
#
# ![image.png](attachment:df1fdd5c-0761-43b0-9bb0-6d3b0797665c.png)

# %% [markdown]
# * data injestion updated
#
# ![image.png](attachment:30f44f18-26a5-4bef-91b8-c0c07080e8f7.png)

# %% [markdown]
# * import the required libraries and creates a dataclass object
#
# ![image.png](attachment:5907051a-c70e-4bb9-982b-d033853fcf78.png)

# %% [markdown]
# * creates the datatransformation class, with the get data trasnformer object module which identifies the numerical and categorial columns , creates the pipelines for the numerical and categorical variables, the pipelines apply imputer and hot encoder and scaling. and then creates the preprocessor which gets returned
#
# ![image.png](attachment:2c4902f4-b405-4d55-8629-14e8cf79025a.png)

# %% [markdown]
# * inititates the data transformation, reads the train and test datasets, separetes the corresponding target and feature subsets for both train and test datasets, runs the preprocessing object and concatenate back the train and test datasets, then saves the preprocessor
#
# ![image.png](attachment:af370d56-630c-44af-af84-20a703d1e2df.png)

# %% [markdown]
# * reinstall the new updated requirements.txt file
#
# ![image.png](attachment:8844157a-5e91-451f-a8c9-0c8d12b74027.png)

# %% [markdown]
# * run the script
#
# ![image.png](attachment:5643d530-21d2-41ca-b496-8f301394facc.png)
#
# * the preprocessor gets saves as a pkl file
#
# ![image.png](attachment:b4534d95-5b88-4423-a370-b1bd5619529d.png)

# %% [markdown]
# # MODEL TRAINER

# %% [markdown]
# * set libraries
#
# ![image.png](attachment:103b08f6-6f14-413d-b588-1a8b0610370e.png)
#
# * set classes for configuration and for training
#
# ![image.png](attachment:de72716a-9def-4145-8b33-4d2d4bafad14.png)
# ![image.png](attachment:d5f47b1c-0855-4d50-a843-6b646d6530a9.png)

# %% [markdown]
# * update the ingestin file to execute the training
#
# ![image.png](attachment:704c4de1-8a6a-4c31-8460-9235bc06a34d.png)
#
# ![image.png](attachment:ade03407-63be-4681-a543-6ecf931409dd.png)

# %% [markdown]
# * utilities has been updated with the evaluate_model function
#
# ![image.png](attachment:0497abf2-312a-4c90-8f22-dc65425d52f0.png)

# %% [markdown]
# * after running the script we get the artifacts folder populated with the saved files, the logs also gets updated
#
# ![image.png](attachment:5ebd6f55-e8a6-46f6-8e93-b55b73e3f3bb.png)

# %% [markdown]
# * update the .git ignore file
#
# ![image.png](attachment:0bf6cddf-017f-4bf8-b210-04cdc14618a3.png)
